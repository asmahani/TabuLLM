# %%
from sklearn.base import is_classifier, is_regressor
from TabuLLM.embed import TextColumnTransformer

def make_pipeline_do_embed(
    features_baseline,
    features_text,
    learner_embedding,
    learner_final,
):
    pass

def make_pipeline(
        features_baseline,
        learner_final, # we expect a value since we use it to determine if this is binary classification or regression
        features_text = None,
        features_embedding = None,
        features_dimred = None,
        learner_embedding = None,
        learner_dimred = None,
        soft_cluster = True,
):
    # exactly one of features_text, features_embedding and features_dimred must be provided
    do_embed = (features_text is not None)
    do_dimred = (features_embedding is not None)
    assert sum([do_embed, do_dimred, features_dimred is not None]) == 1, "Exactly one of features_text, features_embedding and features_dimred must be provided"
    
    # use learner final to determine if this is binary classification or regression
    is_clf = is_classifier(learner_final)
    is_reg = is_regressor(learner_final)
    assert is_clf ^ is_reg, "Learner final must be either a classifier or a regressor"

    # if we must do embedding, check if the learner_embedding is provided
    # if not, we will use a default learner
    if do_embed and (learner_embedding is None):
        learner_embedding = TextColumnTransformer(model_type = 'st')



    pass
# Out:
# c:\Users\alire\anaconda3\envs\devTEFE\Lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %%
import pandas as pd
df = pd.read_csv('../../data/raw.csv')
df.head()
# Out:
#    is_female    age  height  weight  optime  \
# 0          1  18.11     148    80.9     112
# 1          1  18.23     169    56.1     144
# 2          1  16.86     166    61.6     114
# 3          1  16.88     162    44.3     109
# 4          0  18.12     175    70.5     119
#
#                                            diagnoses  \
# 0  155500. Cardiac conduit complication;010125. P...
# 1  091591. Aortic regurgitation;091519. Congenita...
# 2  155516. Cardiac conduit failure;090101. Common...
# 3  010116. Partial anomalous pulmonary venous con...
# 4  155516. Cardiac conduit failure;010133. Left h...
#
#                                           operations  cr_ratio_log  \
# 0             123610. Replacement of cardiac conduit     -0.014599
# 1  121791. Aortic root replacement: valve sparing...      0.366463
# 2  123610. Replacement of cardiac conduit;123452....      0.084899
# 3  120017. Scimitar syndrome (partially anomalous...      0.168335
# ...

# %%
from sklearn.linear_model import LogisticRegression

make_pipeline(
    features_baseline = ['is_female', 'age', 'height', 'weight', 'optime'],
    learner_final = LogisticRegression(max_iter=10, solver = 'newton-cholesky', penalty=None),
    features_text = ['diagnoses', 'operations'],
)
